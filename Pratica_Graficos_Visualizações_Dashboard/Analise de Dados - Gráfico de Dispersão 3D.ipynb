# %% [markdown]
# Gráfico de Dispersão 3D

# %%
#Importação de Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Carregamento de base de Dados
base = pd.read_csv('orchard.csv')
base
# Out:
#     decrease  rowpos  colpos treatment
# 0         57       1       1         D
# 1         95       2       1         E
# 2          8       3       1         B
# 3         69       4       1         H
# 4         92       5       1         G
# ..       ...     ...     ...       ...
# 59        14       4       8         B
# 60        86       5       8         H
# 61        55       6       8         E
# 62         3       7       8         A
# 63        19       8       8         C
#
# [64 rows x 4 columns]

# %%
# Criação do Gráfico 3D, indicando o atributo projection = '3d' e passando tres atributos(decrease, rowpos e colpos)
figura = plt.figure()
eixo = figura.add_subplot(1,1,1, projection = '3d')
eixo.scatter(base.decrease, base.rowpos, base.colpos)
eixo.set_xlabel('Decrease')
eixo.set_ylabel('Rowpos')
eixo.set_zlabel('Colpos')
plt.show()
